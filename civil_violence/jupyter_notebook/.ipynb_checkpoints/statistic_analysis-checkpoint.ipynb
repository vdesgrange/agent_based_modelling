# %%
import numpy as np
import pandas as pd
import scipy
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
def load_plot_archive(path):
    """
    Loads the data from the experiment into RAM
    
    returns:
        - keys df
        - df
    """
    file_path = [path]

    for path in file_path:
        with open(path, 'rb') as f:
            data = np.load(f, allow_pickle=True)[()]
    
    keys = data.keys()
    return keys, data

# %%
def create_df_list(keys, df):
    """
    Creates a list of dataframes
    
    Returns:
        - df list
    """

    df_list = []
    for key in keys:
        df_list.append(total_file_df[key])
    print(df_list)

# %%
def get_outbreaks(data, threshold=50):
    """
    Calculates the outbreaks from the actives data.

    Returns:
        - An array with the outbreak peak sizes.
        - An array with the outbreak durations.
    """
    outbreak_peaks = []
    outbreak_widths = []
    counting = False
    current_peak = 0
    start = 0

    for i in range(len(data)):

        if data[i] >= threshold and not counting:
            counting = True
            if current_peak < data[i]:
                current_peak = data[i]
            start = i

        elif data[i] >= threshold and counting:
            if current_peak < data[i]:
                current_peak = data[i]

        elif data[i] < threshold and counting:
            outbreak_peaks.append(current_peak)
            outbreak_widths.append(i-start)
            current_peak = 0
            counting = False

    # Capture cases where timeline ends in an outbreak.
    # Obviously skewers data, but preferable over 0 or infinite outbreaks.
    if not outbreak_peaks and counting:
        outbreak_peaks.append(current_peak)
        outbreak_widths.append(len(data))
    elif not outbreak_peaks and not counting:
        outbreak_peaks.append(0)
        outbreak_widths.append(0)

    return outbreak_peaks, outbreak_widths

# %%
def create_peakduration_df(name, data):
    """
    Creates a dataframe of the data

    Returns:
        - Pandas.DataFrame Object 
    """

    total_peaks = []
    total_durations = []
    average_outbreaks = []
    for df in df_list:
        peaks , durations = get_outbreaks(df.ACTIVE)
        total_peaks += peaks
        total_durations += durations
        average_outbreaks.append(len(durations))

    df = pd.DataFrame(data={'PeakHeight': total_peaks, 'PeakDuration': total_durations})
    df["Network"] = name
    return df

# %%
def read_filenames(directory):
    """
    Reads the different filenames of a directory
    
    returns:
        - filenames
    """    
    return [directory + name for name in os.listdir(directory)]

# %%
def drop_rows_df(df, columnname, condition):
    """
    Drops rows based on a condition
    
    returns:
        - dataframe
    """
    return df[df[columnname] != condition]

# %%
path = 'data/'
filenames = read_filenames(path)
names = [file.split('_')[5] for file in filenames]

full_df = pd.DataFrame()
for index in range(len(filenames)):
    
    keys, total_file_df = load_plot_archive(filenames[index])
    df_list = create_df_list(keys, total_file_df)
    df_plot = create_peakduration_df(names[index], df_list)
    full_df = pd.concat([full_df, df_plot])

full_df = drop_rows_df(full_df, 'Network', 'run')
full_df = drop_rows_df(full_df, 'PeakDuration', 401)

for key in keys:
    total_file_df[key].ACTIVE[0:8].plot()
# Out:
# [     QUIESCENT  ACTIVE  JAILED  LEGITIMACY  OUTBREAKS
# 0         1110       9       0    0.820000          0
# 1         1008      69      42    0.820000          0
# 2         1008      69      42    0.788022          1
# 3          618     392     109    0.788022          1
# 4          618     392     109    0.764357          1
# ..         ...     ...     ...         ...        ...
# 396        938       0     181    0.817360          5
# 397        969       1     149    0.817360          5
# 398        969       1     149    0.819992          5
# 399        958      21     140    0.819992          5
# 400        958      21     140    0.812462          5
#
# [401 rows x 5 columns],      QUIESCENT  ACTIVE  JAILED  LEGITIMACY  OUTBREAKS
# 0         1143      14       0    0.820000          0
# 1          853     256      48    0.820000          0
# 2          853     256      48    0.784509          1
# 3          333     716     108    0.784509          1
# 4          333     716     108    0.769217          1
# ..         ...     ...     ...         ...        ...
# 396         57     465     635    0.709334          5
# 397         73     430     654    0.709334          5
# 398         73     430     654    0.704133          5
# 399         67     409     681    0.704133          5
# 400         67     409     681    0.697166          5
#
# [401 rows x 5 columns],      QUIESCENT  ACTIVE  JAILED  LEGITIMACY  OUTBREAKS
# 0         1139       7       0    0.820000          0
# 1          900     209      37    0.820000          0
# 2          900     209      37    0.792642          1
# 3          387     673      86    0.792642          1
# 4          387     673      86    0.780408          1
# ..         ...     ...     ...         ...        ...
# 396        104     293     749    0.701670          1
# 397        103     294     749    0.701670          1
# 398        103     294     749    0.702017          1
# 399        106     291     749    0.702017          1
# 400        106     291     749    0.702080          1
#
# [401 rows x 5 columns],      QUIESCENT  ACTIVE  JAILED  LEGITIMACY  OUTBREAKS
# 0         1103      22       0    0.820000          0
# 1          832     239      54    0.820000          0
# 2          832     239      54    0.777890          1
# 3          310     703     112    0.777890          1
# 4          310     703     112    0.770078          1
# ..         ...     ...     ...         ...        ...
# 396         90     162     873    0.576532          2
# 397        108     143     874    0.576532          2
# 398        108     143     874    0.572830          2
# 399         92     145     888    0.572830          2
# 400         92     145     888    0.560034          2
#
# [401 rows x 5 columns],      QUIESCENT  ACTIVE  JAILED  LEGITIMACY  OUTBREAKS
# 0         1147       9       0    0.820000          0
# 1          947     168      41    0.820000          0
# 2          947     168      41    0.789112          1
# 3          372     687      97    0.789112          1
# 4          372     687      97    0.773152          1
# ..         ...     ...     ...         ...        ...
# 396        116     159     881    0.593756          1
# 397         78     188     890    0.593756          1
# 398         78     188     890    0.591118          1
# 399         85     184     887    0.591118          1
# 400         85     184     887    0.591709          1
#
# [401 rows x 5 columns],      QUIESCENT  ACTIVE  JAILED  LEGITIMACY  OUTBREAKS
# 0         1099      12       0    0.820000          0
# 1          777     290      44    0.820000          0
# 2          777     290      44    0.786186          1
# 3          295     721      95    0.786186          1
# 4          295     721      95    0.776637          1
# ..         ...     ...     ...         ...        ...
# 396         97     223     791    0.660321          1
# 397         86     225     800    0.660321          1
# 398         86     225     800    0.657481          1
# 399         88     217     806    0.657481          1
# 400         88     217     806    0.653754          1
#
# [401 rows x 5 columns],      QUIESCENT  ACTIVE  JAILED  LEGITIMACY  OUTBREAKS
# 0         1117      19       0    0.820000          0
# 1          839     250      47    0.820000          0
# 2          839     250      47    0.783857          1
# 3          319     714     103    0.783857          1
# 4          319     714     103    0.770779          1
# ..         ...     ...     ...         ...        ...
# 396        136     120     880    0.572612          2
# 397        146     118     872    0.572612          2
# 398        146     118     872    0.584247          2
# 399        150     118     868    0.584247          2
# 400        150     118     868    0.589342          2
#
# [401 rows x 5 columns],      QUIESCENT  ACTIVE  JAILED  LEGITIMACY  OUTBREAKS
# 0         1127      22       0    0.820000          0
# 1          765     326      58    0.820000          0
# 2          765     326      58    0.775655          1
# 3          282     749     118    0.775655          1
# 4          282     749     118    0.765905          1
# ..         ...     ...     ...         ...        ...
# 396         78     150     921    0.516878          6
# 397         91     125     933    0.516878          6
# 398         91     125     933    0.491468          6
# 399        101     107     941    0.491468          6
# 400        101     107     941    0.478379          6
#
# [401 rows x 5 columns],      QUIESCENT  ACTIVE  JAILED  LEGITIMACY  OUTBREAKS
# 0         1138      10       0    0.820000          0
# 1          954     154      40    0.820000          0
# 2          954     154      40    0.790397          1
# 3          402     645     101    0.790397          1
# 4          402     645     101    0.770374          1
# ..         ...     ...     ...         ...        ...
# 396         64     175     909    0.544018          5
# 397         87     142     919    0.544018          5
# 398         87     142     919    0.520736          5
# 399        101     117     930    0.520736          5
# 400        101     117     930    0.499473          5
#
# [401 rows x 5 columns],      QUIESCENT  ACTIVE  JAILED  LEGITIMACY  OUTBREAKS
# 0         1128      20       0    0.820000          0
# 1          918     175      55    0.820000          0
# 2          918     175      55    0.778737          1
# 3          401     618     129    0.778737          1
# 4          401     618     129    0.753547          1
# ..         ...     ...     ...         ...        ...
# 396       1053       0      95    0.816878          4
# 397       1071       0      77    0.816878          4
# 398       1071       0      77    0.819223          4
# 399       1082       1      65    0.819223          4
# 400       1082       1      65    0.818485          4
#
# [401 rows x 5 columns],      QUIESCENT  ACTIVE  JAILED  LEGITIMACY  OUTBREAKS
# 0         1114      19       0    0.820000          0
# 1          927     151      55    0.820000          0
# 2          927     151      55    0.778163          1
# 3          357     650     126    0.778163          1
# 4          357     650     126    0.759236          1
# ..         ...     ...     ...         ...        ...
# 396         47     377     709    0.658761          5
# 397         54     335     744    0.658761          5
# 398         54     335     744    0.641537          5
# 399         55     300     778    0.641537          5
# 400         55     300     778    0.621583          5
#
# [401 rows x 5 columns],      QUIESCENT  ACTIVE  JAILED  LEGITIMACY  OUTBREAKS
# 0         1174      11       0    0.820000          0
# 1          775     368      42    0.820000          0
# 2          775     368      42    0.789869          1
# 3          328     764      93    0.789869          1
# 4          328     764      93    0.780596          1
# ..         ...     ...     ...         ...        ...
# 396        109     314     762    0.707884          1
# 397        103     321     761    0.707884          1
# 398        103     321     761    0.708011          1
# 399         97     326     762    0.708011          1
# 400         97     326     762    0.707834          1
#
# [401 rows x 5 columns],      QUIESCENT  ACTIVE  JAILED  LEGITIMACY  OUTBREAKS
# 0         1153      13       0    0.820000          0
# 1          752     364      50    0.820000          0
# 2          752     364      50    0.783262          1
# 3          282     781     103    0.783262          1
# 4          282     781     103    0.775156          1
# ..         ...     ...     ...         ...        ...
# 396         93     221     852    0.643282          1
# 397        101     226     839    0.643282          1
# 398        101     226     839    0.648839          1
# 399         89     232     845    0.648839          1
# 400         89     232     845    0.648247          1
#
# [401 rows x 5 columns],      QUIESCENT  ACTIVE  JAILED  LEGITIMACY  OUTBREAKS
# 0         1124      19       0    0.820000          0
# 1          893     192      58    0.820000          0
# 2          893     192      58    0.776166          1
# 3          405     612     126    0.776166          1
# 4          405     612     126    0.759604          1
# ..         ...     ...     ...         ...        ...
# 396        840       6     297    0.818061          5
# 397        840      20     283    0.818061          5
# 398        840      20     283    0.805693          5
# 399        834      26     283    0.805693          5
# 400        834      26     283    0.792099          5
#
# [401 rows x 5 columns],      QUIESCENT  ACTIVE  JAILED  LEGITIMACY  OUTBREAKS
# 0         1137      20       0    0.820000          0
# 1          929     170      58    0.820000          0
# 2          929     170      58    0.776724          1
# 3          382     643     132    0.776724          1
# 4          382     643     132    0.756916          1
# ..         ...     ...     ...         ...        ...
# 396        574       0     583    0.819988          5
# 397        617       0     540    0.819988          5
# 398        617       0     540    0.817342          5
# 399        667       5     485    0.817342          5
# 400        667       5     485    0.813890          5
#
# [401 rows x 5 columns],      QUIESCENT  ACTIVE  JAILED  LEGITIMACY  OUTBREAKS
# 0         1098      19       0    0.820000          0
# 1          722     339      56    0.820000          0
# 2          722     339      56    0.776720          1
# 3          291     710     116    0.776720          1
# 4          291     710     116    0.767746          1
# ..         ...     ...     ...         ...        ...
# 396         60     288     769    0.651662          5
# 397         64     261     792    0.651662          5
# 398         64     261     792    0.637396          5
# 399         71     241     805    0.637396          5
# 400         71     241     805    0.626376          5
#
# [401 rows x 5 columns],      QUIESCENT  ACTIVE  JAILED  LEGITIMACY  OUTBREAKS
# 0         1110      14       0    0.820000          0
# 1          947     126      51    0.820000          0
# 2          947     126      51    0.781025          1
# 3          409     595     120    0.781025          1
# 4          409     595     120    0.760159          1
# ..         ...     ...     ...         ...        ...
# 396         91     405     628    0.685390          6
# 397         87     385     652    0.685390          6
# 398         87     385     652    0.677751          6
# 399         87     358     679    0.677751          6
# 400         87     358     679    0.668209          6
#
# [401 rows x 5 columns],      QUIESCENT  ACTIVE  JAILED  LEGITIMACY  OUTBREAKS
# 0         1117      20       0    0.820000          0
# 1          868     214      55    0.820000          0
# 2          868     214      55    0.778318          1
# 3          347     672     118    0.778318          1
# 4          347     672     118    0.766380          1
# ..         ...     ...     ...         ...        ...
# 396        422      17     698    0.787088          5
# 397        482       4     651    0.787088          5
# 398        482       4     651    0.791740          5
# 399        543       1     593    0.791740          5
# 400        543       1     593    0.813034          5
#
# [401 rows x 5 columns],      QUIESCENT  ACTIVE  JAILED  LEGITIMACY  OUTBREAKS
# 0         1138      10       0    0.820000          0
# 1          686     423      39    0.820000          0
# 2          686     423      39    0.791163          1
# 3          260     803      85    0.791163          1
# 4          260     803      85    0.783501          1
# ..         ...     ...     ...         ...        ...
# 396         84     345     719    0.721659          1
# 397         93     338     717    0.721659          1
# 398         93     338     717    0.722037          1
# 399         91     340     717    0.722037          1
# 400         91     340     717    0.722131          1
#
# [401 rows x 5 columns],      QUIESCENT  ACTIVE  JAILED  LEGITIMACY  OUTBREAKS
# 0         1132      21       0    0.820000          0
# 1          851     239      63    0.820000          0
# 2          851     239      63    0.772606          1
# 3          298     726     129    0.772606          1
# 4          298     726     129    0.763608          1
# ..         ...     ...     ...         ...        ...
# 396         63     238     852    0.599489          5
# 397         66     207     880    0.599489          5
# 398         66     207     880    0.571507          5
# 399         64     187     902    0.571507          5
# 400         64     187     902    0.542682          5
#
# [401 rows x 5 columns],      QUIESCENT  ACTIVE  JAILED  LEGITIMACY  OUTBREAKS
# 0         1113      15       0    0.820000          0
# 1          971     116      41    0.820000          0
# 2          971     116      41    0.789071          1
# 3          475     544     109    0.789071          1
# 4          475     544     109    0.762504          1
# ..         ...     ...     ...         ...        ...
# 396        503       0     625    0.816701          5
# 397        548       0     580    0.816701          5
# 398        548       0     580    0.819987          5
# 399        609       0     519    0.819987          5
# 400        609       0     519    0.818653          5
#
# [401 rows x 5 columns],      QUIESCENT  ACTIVE  JAILED  LEGITIMACY  OUTBREAKS
# 0         1149      14       0    0.820000          0
# 1          788     327      48    0.820000          0
# 2          788     327      48    0.784700          1
# 3          268     793     102    0.784700          1
# 4          268     793     102    0.775200          1
# ..         ...     ...     ...         ...        ...
# 396         96     255     812    0.664794          1
# 397         86     262     815    0.664794          1
# 398         86     262     815    0.663815          1
# 399         93     254     816    0.663815          1
# 400         93     254     816    0.663102          1
#
# [401 rows x 5 columns],      QUIESCENT  ACTIVE  JAILED  LEGITIMACY  OUTBREAKS
# 0         1127      17       0    0.820000          0
# 1          730     363      51    0.820000          0
# 2          730     363      51    0.780988          1
# 3          233     802     109    0.780988          1
# 4          233     802     109    0.770608          1
# ..         ...     ...     ...         ...        ...
# 396        108     133     903    0.558283          1
# 397        121     119     904    0.558283          1
# 398        121     119     904    0.552702          1
# 399        131     113     900    0.552702          1
# 400        131     113     900    0.554457          1
#
# [401 rows x 5 columns],      QUIESCENT  ACTIVE  JAILED  LEGITIMACY  OUTBREAKS
# 0         1116      19       0    0.820000          0
# 1          887     195      53    0.820000          0
# 2          887     195      53    0.779076          1
# 3          348     669     118    0.779076          1
# 4          348     669     118    0.764742          1
# ..         ...     ...     ...         ...        ...
# 396        625       8     502    0.814809          5
# 397        642      24     469    0.814809          5
# 398        642      24     469    0.799036          5
# 399        647      33     455    0.799036          5
# 400        647      33     455    0.789318          5
#
# [401 rows x 5 columns],      QUIESCENT  ACTIVE  JAILED  LEGITIMACY  OUTBREAKS
# 0         1148      17       0    0.820000          0
# 1          881     232      52    0.820000          0
# 2          881     232      52    0.781689          1
# 3          386     670     109    0.781689          1
# 4          386     670     109    0.770843          1
# ..         ...     ...     ...         ...        ...
# 396         84     261     820    0.647143          4
# 397         75     253     837    0.647143          4
# 398         75     253     837    0.637740          4
# 399         76     237     852    0.637740          4
# 400         76     237     852    0.627298          4
#
# [401 rows x 5 columns],      QUIESCENT  ACTIVE  JAILED  LEGITIMACY  OUTBREAKS
# 0         1124       9       0    0.820000          0
# 1         1046      45      42    0.820000          0
# 2         1046      45      42    0.788433          0
# 3          856     181      96    0.788433          0
# 4          856     181      96    0.774503          1
# ..         ...     ...     ...         ...        ...
# 396         53     334     746    0.621410          5
# 397         44     294     795    0.621410          5
# 398         44     294     795    0.589088          5
# 399         51     245     837    0.589088          5
# 400         51     245     837    0.549378          5
#
# [401 rows x 5 columns],      QUIESCENT  ACTIVE  JAILED  LEGITIMACY  OUTBREAKS
# 0         1137      13       0    0.820000          0
# 1          944     164      42    0.820000          0
# 2          944     164      42    0.788917          1
# 3          374     671     105    0.788917          1
# 4          374     671     105    0.769386          1
# ..         ...     ...     ...         ...        ...
# 396        605     272     273    0.764442          5
# 397        257     588     305    0.764442          5
# 398        257     588     305    0.755144          5
# 399        141     676     333    0.755144          5
# 400        141     676     333    0.751961          5
#
# [401 rows x 5 columns],      QUIESCENT  ACTIVE  JAILED  LEGITIMACY  OUTBREAKS
# 0         1144      14       0    0.820000          0
# 1          992     120      46    0.820000          0
# 2          992     120      46    0.785342          1
# 3          494     548     116    0.785342          1
# 4          494     548     116    0.761875          1
# ..         ...     ...     ...         ...        ...
# 396         50     357     751    0.645392          5
# 397         51     318     789    0.645392          5
# 398         51     318     789    0.624677          5
# 399         46     279     833    0.624677          5
# 400         46     279     833    0.595386          5
#
# [401 rows x 5 columns],      QUIESCENT  ACTIVE  JAILED  LEGITIMACY  OUTBREAKS
# 0         1102      21       0    0.820000          0
# 1          912     160      51    0.820000          0
# 2          912     160      51    0.780989          1
# 3          407     599     117    0.780989          1
# 4          407     599     117    0.760271          1
# ..         ...     ...     ...         ...        ...
# 396        928       0     195    0.819115          5
# 397        956       0     167    0.819115          5
# 398        956       0     167    0.819141          5
# 399        974       2     147    0.819141          5
# 400        974       2     147    0.814118          5
#
# [401 rows x 5 columns],      QUIESCENT  ACTIVE  JAILED  LEGITIMACY  OUTBREAKS
# 0         1146      17       0    0.820000          0
# 1          792     325      46    0.820000          0
# 2          792     325      46    0.785497          1
# 3          321     742     100    0.785497          1
# 4          321     742     100    0.775350          1
# ..         ...     ...     ...         ...        ...
# 396        110     202     851    0.640712          1
# 397        106     196     861    0.640712          1
# 398        106     196     861    0.636649          1
# 399        106     199     858    0.636649          1
# 400        106     199     858    0.636506          1
#
# [401 rows x 5 columns],      QUIESCENT  ACTIVE  JAILED  LEGITIMACY  OUTBREAKS
# 0         1122      11       0    0.820000          0
# 1         1026      69      38    0.820000          0
# 2         1026      69      38    0.790795          1
# 3          576     452     105    0.790795          1
# 4          576     452     105    0.765516          1
# ..         ...     ...     ...         ...        ...
# 396         73     433     627    0.697203          6
# 397         74     406     653    0.697203          6
# 398         74     406     653    0.689545          6
# 399         61     381     691    0.689545          6
# 400         61     381     691    0.677821          6
#
# [401 rows x 5 columns],      QUIESCENT  ACTIVE  JAILED  LEGITIMACY  OUTBREAKS
# 0         1152      13       0    0.820000          0
# 1          929     180      56    0.820000          0
# 2          929     180      56    0.777854          1
# 3          391     652     122    0.777854          1
# 4          391     652     122    0.765159          1
# ..         ...     ...     ...         ...        ...
# 396        123      86     956    0.483336          5
# 397        142      66     957    0.483336          5
# 398        142      66     957    0.504496          5
# 399        155      57     953    0.504496          5
# 400        155      57     953    0.526283          5
#
# [401 rows x 5 columns],      QUIESCENT  ACTIVE  JAILED  LEGITIMACY  OUTBREAKS
# 0         1137      16       0    0.820000          0
# 1          821     284      48    0.820000          0
# 2          821     284      48    0.784380          1
# 3          352     709      92    0.784380          1
# 4          352     709      92    0.779037          1
# ..         ...     ...     ...         ...        ...
# 396         79     290     784    0.690209          1
# 397         96     277     780    0.690209          1
# 398         96     277     780    0.690251          1
# 399         92     278     783    0.690251          1
# 400         92     278     783    0.689478          1
#
# [401 rows x 5 columns],      QUIESCENT  ACTIVE  JAILED  LEGITIMACY  OUTBREAKS
# 0         1118      15       0    0.820000          0
# 1          829     249      55    0.820000          0
# 2          829     249      55    0.777403          1
# 3          312     704     117    0.777403          1
# 4          312     704     117    0.766941          1
# ..         ...     ...     ...         ...        ...
# 396         83     179     871    0.572172          5
# 397         83     164     886    0.572172          5
# 398         83     164     886    0.553791          5
# 399         88     152     893    0.553791          5
# 400         88     152     893    0.540003          5
#
# [401 rows x 5 columns],      QUIESCENT  ACTIVE  JAILED  LEGITIMACY  OUTBREAKS
# 0         1145      15       0    0.820000          0
# 1          866     251      43    0.820000          0
# 2          866     251      43    0.787699          1
# 3          403     657     100    0.787699          1
# 4          403     657     100    0.772313          1
# ..         ...     ...     ...         ...        ...
# 396        647      36     477    0.786603          2
# 397        630      66     464    0.786603          2
# 398        630      66     464    0.775093          3
# 399        486     186     488    0.775093          3
# 400        486     186     488    0.750519          3
#
# [401 rows x 5 columns],      QUIESCENT  ACTIVE  JAILED  LEGITIMACY  OUTBREAKS
# 0         1115      15       0    0.820000          0
# 1          885     195      50    0.820000          0
# 2          885     195      50    0.781278          1
# 3          406     614     110    0.781278          1
# 4          406     614     110    0.767524          1
# ..         ...     ...     ...         ...        ...
# 396         99     135     896    0.530175          5
# 397        108     125     897    0.530175          5
# 398        108     125     897    0.523826          5
# 399        133     101     896    0.523826          5
# 400        133     101     896    0.526783          5
#
# [401 rows x 5 columns],      QUIESCENT  ACTIVE  JAILED  LEGITIMACY  OUTBREAKS
# 0         1142       6       0    0.820000          0
# 1          850     249      49    0.820000          0
# 2          850     249      49    0.783439          1
# 3          327     717     104    0.783439          1
# 4          327     717     104    0.773600          1
# ..         ...     ...     ...         ...        ...
# 396         84     199     865    0.617342          1
# 397        105     189     854    0.617342          1
# 398        105     189     854    0.621593          1
# 399        102     195     851    0.621593          1
# 400        102     195     851    0.625104          1
#
# [401 rows x 5 columns],      QUIESCENT  ACTIVE  JAILED  LEGITIMACY  OUTBREAKS
# 0         1121      17       0    0.820000          0
# 1          711     372      55    0.820000          0
# 2          711     372      55    0.778356          1
# 3          262     767     109    0.778356          1
# 4          262     767     109    0.771666          1
# ..         ...     ...     ...         ...        ...
# 396        126     140     872    0.589572          1
# 397        111     161     866    0.589572          1
# 398        111     161     866    0.596512          1
# 399         96     167     875    0.596512          1
# 400         96     167     875    0.593378          1
#
# [401 rows x 5 columns],      QUIESCENT  ACTIVE  JAILED  LEGITIMACY  OUTBREAKS
# 0         1137      21       0    0.820000          0
# 1          680     434      44    0.820000          0
# 2          680     434      44    0.787612          1
# 3          271     798      89    0.787612          1
# 4          271     798      89    0.781901          1
# ..         ...     ...     ...         ...        ...
# 396         84     348     726    0.718205          1
# 397         98     336     724    0.718205          1
# 398         98     336     724    0.718142          1
# 399         98     344     716    0.718142          1
# 400         98     344     716    0.719795          1
#
# [401 rows x 5 columns],      QUIESCENT  ACTIVE  JAILED  LEGITIMACY  OUTBREAKS
# 0         1099      23       0    0.820000          0
# 1          936     133      53    0.820000          0
# 2          936     133      53    0.779345          1
# 3          400     598     124    0.779345          1
# 4          400     598     124    0.759648          1
# ..         ...     ...     ...         ...        ...
# 396         95      84     943    0.360982          5
# 397        114      42     966    0.360982          5
# 398        114      42     966    0.295745          5
# 399        143      14     965    0.295745          5
# 400        143      14     965    0.377991          5
#
# [401 rows x 5 columns]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-732376cdae1a> in <module>
#       8     keys, total_file_df = load_plot_archive(filenames[index])
#       9     df_list = create_df_list(keys, total_file_df)
# ---> 10     df_plot = create_peakduration_df(names[index], df_list)
#      11     full_df = pd.concat([full_df, df_plot])
#      12
#
# <ipython-input-5-09a9eec8839d> in create_peakduration_df(name, data)
#      10     total_durations = []
#      11     average_outbreaks = []
# ---> 12     for df in df_list:
#      13         peaks , durations = get_outbreaks(df.ACTIVE)
#      14         total_peaks += peaks
#
# TypeError: 'NoneType' object is not iterable

# %%
sns.displot(full_df, x="PeakHeight", hue='Network', fill=True, kind='kde')
sns.displot(full_df, x='PeakDuration', hue='Network', fill=True, kind='kde')
